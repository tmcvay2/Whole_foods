# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_csv(pwd + "/Whole_Foods_loc.csv")
dataset
# Out:
#       Longitude   Latitude Whole Foods Store                     Address  \
# 0    -86.752554  33.460451       Whole Foods   3100 Cahaba Village Plaza
# 1    -86.590416  34.712443       Whole Foods       2501 Memorial Pkwy SW
# 2    -88.150461  30.676137       Whole Foods           3968 Airport Blvd
# 3    -86.171404  32.357815       Whole Foods              1450 Taylor Rd
# 4    -94.145078  36.113563       Whole Foods       3425 N College Avenue
# ..          ...        ...               ...                         ...
# 454 -122.536232  47.227390       Whole Foods    3515 Bridgeport Way West
# 455 -122.507387  45.615538       Whole Foods  815 Southeast 160th Avenue
# 456  -89.443819  43.075100       Whole Foods         3313 University Ave
# 457  -87.883706  43.060374       Whole Foods         2305 N Prospect Ave
# 458  -88.051722  43.074810       Whole Foods     11100 W Burleigh Street
#
#                  City States & Territory Zip Code
# 0          Birmingham            Alabama    35242
# 1          Huntsville            Alabama    35800
# 2              Mobile            Alabama    36607
# 3          Montgomery            Alabama    36116
# 4        Fayetteville           Arkansas    72702
# ..                ...                ...      ...
# 454  University Place         Washington    98465
# 455         Vancouver         Washington    98682
# 456           Madison          Wisconsin    53704
# 457         Milwaukee          Wisconsin    53210
# 458         Wauwatosa          Wisconsin    53221
#
# [459 rows x 7 columns]

# %%
wf1 = dataset.groupby(["States & Territory"])["Whole Foods Store"].count().reset_index().sort_values(by = ['Whole Foods Store'],ascending=False)[:7]
wf1
# Out:
#    States & Territory  Whole Foods Store
# 5          California                 86
# 41              Texas                 31
# 21      Massachusetts                 31
# 13           Illinois                 27
# 9             Florida                 26
# 6            Colorado                 21
# 31           New York                 17

# %%
labels = wf1["States & Territory"]
vals = wf1["Whole Foods Store"]


fig, ax = plt.subplots(edgecolor = 'k')
ax.bar(labels,vals)
plt.xticks(rotation = 45, fontsize = 'medium')
plt.show()

# %%
wf2 = pd.read_csv("Whole_Foods_Loc.csv", usecols = ['City', 'States & Territory'])
wf2
# Out:
#                  City States & Territory
# 0          Birmingham            Alabama
# 1          Huntsville            Alabama
# 2              Mobile            Alabama
# 3          Montgomery            Alabama
# 4        Fayetteville           Arkansas
# ..                ...                ...
# 454  University Place         Washington
# 455         Vancouver         Washington
# 456           Madison          Wisconsin
# 457         Milwaukee          Wisconsin
# 458         Wauwatosa          Wisconsin
#
# [459 rows x 2 columns]

# %%
total_city = dataset.groupby(['City'])["States & Territory"].count().reset_index().sort_values(by = ["States & Territory"], ascending=False)[:10]
total_city
# Out:
#               City  States & Territory
# 52         Chicago                  12
# 197       New York                   8
# 125        Houston                   7
# 258  San Francisco                   7
# 158    Los Angeles                   6
# 235       Portland                   5
# 13         Atlanta                   4
# 316     Washington                   4
# 75          Denver                   4
# 308      Vancouver                   4

# %%
labels = total_city["City"]
vals = total_city["States & Territory"]


fig, ax = plt.subplots(edgecolor = 'k')
ax.bar(labels,vals)
plt.xticks(rotation=45, fontsize = 'medium')
plt.show()

# %%
wf4 = dataset[(dataset["States & Territory"] == "California")]
wf4
# Out:
#       Longitude   Latitude Whole Foods Store                 Address  \
# 23  -122.297204  37.880249       Whole Foods      1025 Gilman Street
# 24  -122.259834  37.856090       Whole Foods      3000 Telegraph Ave
# 25  -118.397859  34.069018       Whole Foods   239 North Crescent Dr
# 26  -117.852125  33.909734       Whole Foods       3301 Imperial Hwy
# 27  -121.931550  37.292780       Whole Foods   1690 South Bascom Ave
# ..          ...        ...               ...                     ...
# 104 -118.470077  34.001582       Whole Foods        225 Lincoln Blvd
# 105 -122.055191  37.893605       Whole Foods         1333 Newell Ave
# 106 -122.015358  37.925926       Whole Foods  2941 Ygnacio Valley Rd
# 107 -118.360909  34.090968       Whole Foods  7871 Santa Monica Blvd
# 108 -118.596427  34.167794       Whole Foods      21347 Ventura Blvd
#
#                City States & Territory Zip Code
# 23         Berkeley         California    94709
# 24         Berkeley         California    94704
# 25    Beverly Hills         California    90209
# 26             Brea         California    92822
# 27         Campbell         California    95007
# ..              ...                ...      ...
# 104          Venice         California    90290
# 105    Walnut Creek         California    94595
# 106    Walnut Creek         California    94597
# 107  West Hollywood         California    90045
# 108  Woodland Hills         California    91363
#
# [86 rows x 7 columns]

# %%
graph = wf4.groupby(["City"])["States & Territory"].count().reset_index().sort_values(by = ["States & Territory"], ascending=False)[:10]
graph
# Out:
#              City  States & Territory
# 43  San Francisco                   7
# 23    Los Angeles                   6
# 53   Santa Monica                   3
# 0        Berkeley                   2
# 56   Sherman Oaks                   2
# 25    Mill Valley                   2
# 44       San Jose                   2
# 54     Santa Rosa                   2
# 35       Pasadena                   2
# 63   Walnut Creek                   2

# %%
labels = graph["City"]
vals = graph["States & Territory"]


fig, ax = plt.subplots(edgecolor = 'k')
ax.bar(labels,vals)
plt.xticks(rotation=45, fontsize = 'medium')
plt.show()

# %%
il = dataset[(dataset["States & Territory"] == "Illinois")]
il
# Out:
#      Longitude   Latitude Whole Foods Store                        Address  \
# 184 -87.646896  41.882469       Whole Foods             1 N Halsted Street
# 185 -87.639083  41.868482       Whole Foods                1101 S Canal St
# 186 -87.653223  41.910910       Whole Foods        1550 N Kingsbury Street
# 187 -87.621323  41.891365       Whole Foods                255 E Grand Ave
# 188 -87.629230  41.894991       Whole Foods               30 West Huron St
# 189 -87.668839  41.941633       Whole Foods             3300 N Ashland Ave
# 190 -87.649632  41.948359       Whole Foods              3640 N Halsted St
# 191 -87.588180  41.801872       Whole Foods           5118 S Lake Park Ave
# 192 -87.659653  41.991081       Whole Foods            6009 North Broadway
# 193 -87.748454  41.990167       Whole Foods              6020 N Cicero Ave
# 194 -87.646271  41.779968       Whole Foods              832 W 63rd Street
# 195 -87.653265  41.925347       Whole Foods      959 West Fullerton Avenue
# 196 -87.847080  42.166746       Whole Foods                760 Waukegan Rd
# 197 -87.962748  41.894224       Whole Foods          215 S Illinois Rte 83
# 198 -87.679962  42.037889       Whole Foods               1111 Chicago Ave
# 199 -87.679513  42.046900       Whole Foods               1640 Chicago Ave
# 200 -87.702390  42.068532       Whole Foods            2748 Green Bay Road
# 201 -87.918195  41.817868       Whole Foods                500 E Ogden Ave
# 202 -88.044486  42.158736       Whole Foods              20281 N Rand Road
# 203 -88.200212  41.747397       Whole Foods             2607 W 75th Street
# 204 -87.800177  42.105537       Whole Foods                840 Willow Road
# 205 -87.854439  41.613257       Whole Foods          15260 S LaGrange Road
# 206 -87.825057  42.010810       Whole Foods                225 W Touhy Ave
# 207 -87.805994  41.888407       Whole Foods                   7245 Lake St
# 208 -88.036464  42.042261       Whole Foods            750 N Martingale Rd
# 209 -88.101832  41.830752       Whole Foods          89 Danada Square East
# 210 -87.947334  41.772834       Whole Foods  6300 S Robert Kingery Highway
#
#              City States & Territory Zip Code
# 184       Chicago           Illinois    60660
# 185       Chicago           Illinois    60606
# 186       Chicago           Illinois    60641
# 187       Chicago           Illinois    60610
# 188       Chicago           Illinois    60653
# 189       Chicago           Illinois    60656
# 190       Chicago           Illinois    60612
# 191       Chicago           Illinois    60614
# 192       Chicago           Illinois    60659
# 193       Chicago           Illinois    60645
# 194       Chicago           Illinois    60620
# 195       Chicago           Illinois    60613
# 196     Deerfield           Illinois    60014
# 197      Elmhurst           Illinois    60125
# 198      Evanston           Illinois    60201
# 199      Evanston           Illinois    60200
# 200      Evanston           Illinois    60200
# 201      Hinsdale           Illinois    60520
# 202       Kildeer           Illinois    60073
# 203    Naperville           Illinois    60539
# 204    Northbrook           Illinois    60061
# 205   Orland Park           Illinois    60461
# 206    Park Ridge           Illinois    60067
# 207  River Forest           Illinois    60304
# 208    Schaumburg           Illinois    60172
# 209       Wheaton           Illinois    60186
# 210   Willowbrook           Illinois    60526

# %%
len(il["City"] == "Chicago")
# Out:
# 27

# %%
wf5 = il.groupby(["City"])["States & Territory"].count().reset_index().sort_values(by = ["States & Territory"], ascending=False)[:10]
wf5
# Out:
#           City  States & Territory
# 0      Chicago                  12
# 3     Evanston                   3
# 1    Deerfield                   1
# 2     Elmhurst                   1
# 4     Hinsdale                   1
# 5      Kildeer                   1
# 6   Naperville                   1
# 7   Northbrook                   1
# 8  Orland Park                   1
# 9   Park Ridge                   1

# %%
labels = wf5["City"]
values = wf5["States & Territory"]


fig, ax = plt.subplots(edgecolor = 'k')
ax.bar(labels,vals)
plt.xticks(rotation=45, fontsize = 'medium')
plt.show()

# %%
tx = dataset[(dataset["States & Territory"] == "Texas")]
#tx

# %%
wf6 =tx.groupby(["City"])["States & Territory"].count().reset_index().sort_values(by = ["States & Territory"], ascending=False)[:10]
wf6
# Out:
#                 City  States & Territory
# 11           Houston                   7
# 2             Austin                   4
# 5             Dallas                   4
# 15       San Antonio                   2
# 0            Addison                   1
# 10  Highland Village                   1
# 16        Sugar Land                   1
# 14        Richardson                   1
# 13             Plano                   1
# 12              Katy                   1

# %%
labels = wf6["City"]
values = wf6["States & Territory"]


fig, ax = plt.subplots(edgecolor = 'k')
ax.bar(labels,values)
plt.xticks(rotation=45, fontsize = 'medium')
plt.show()

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
import descartes
import fiona

# %matplotlib inline

# %%
us_map = gpd.read_file("cb_2018_us_state_500k.shp")
#us_map

# %%
cal = pd.read_csv("Whole_Foods_Loc.csv", names= ["Longitude", "Latitude", "Store Name", "Address" ,"City", "State", "Zip Code"], usecols= ["Longitude", "Latitude", "State"], skiprows = 24, nrows = 86)
crs = {'init': 'epsg:4326'}
cal
# Out:
#      Longitude   Latitude       State
# 0  -122.297204  37.880249  California
# 1  -122.259834  37.856090  California
# 2  -118.397859  34.069018  California
# 3  -117.852125  33.909734  California
# 4  -121.931550  37.292780  California
# ..         ...        ...         ...
# 81 -118.470077  34.001582  California
# 82 -122.055191  37.893605  California
# 83 -122.015358  37.925926  California
# 84 -118.360909  34.090968  California
# 85 -118.596427  34.167794  California
#
# [86 rows x 3 columns]

# %%
geometry = [Point(xy) for xy in zip( cal["Longitude"], cal["Latitude"])]
#geometry

# %%
geo_df = gpd.GeoDataFrame(cal ,crs = crs, geometry = geometry)
geo_df
# Out:
# /opt/miniconda3/envs/data_science/lib/python3.9/site-packages/pyproj/crs/crs.py:68: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#      Longitude   Latitude       State                     geometry
# 0  -122.297204  37.880249  California  POINT (-122.29720 37.88025)
# 1  -122.259834  37.856090  California  POINT (-122.25983 37.85609)
# 2  -118.397859  34.069018  California  POINT (-118.39786 34.06902)
# 3  -117.852125  33.909734  California  POINT (-117.85212 33.90973)
# 4  -121.931550  37.292780  California  POINT (-121.93155 37.29278)
# ..         ...        ...         ...                          ...
# 81 -118.470077  34.001582  California  POINT (-118.47008 34.00158)
# 82 -122.055191  37.893605  California  POINT (-122.05519 37.89361)
# 83 -122.015358  37.925926  California  POINT (-122.01536 37.92593)
# 84 -118.360909  34.090968  California  POINT (-118.36091 34.09097)
# 85 -118.596427  34.167794  California  POINT (-118.59643 34.16779)
#
# [86 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize = (15,15))

us_map[us_map.NAME == 'California'].plot(ax = ax, figsize = (20,20), alpha = .5, color = 'green')

geo_df[geo_df["State"] == "California"].plot(ax = ax, markersize = 20, color = "blue", marker = "o", label = "Whole Foods")

plt.show()
